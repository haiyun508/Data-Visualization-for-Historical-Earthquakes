# %%
# Import Dependencies
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine,inspect
import os
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# read player_allstar csv file, drop unnecessary columns
csv_file="earthquake.csv"
earthquakes_df=pd.read_csv(csv_file)
earthquakes_df=earthquakes_df[["ID","Date","Latitude","Longitude","Depth","Magnitude"]]
earthquakes_df
# Out:
#                  ID        Date  Latitude  Longitude   Depth  Magnitude
# 0      ISCGEM860706  01/02/1965   19.2460   145.6160  131.60        6.0
# 1      ISCGEM860737  01/04/1965    1.8630   127.3520   80.00        5.8
# 2      ISCGEM860762  01/05/1965  -20.5790  -173.9720   20.00        6.2
# 3      ISCGEM860856  01/08/1965  -59.0760   -23.5570   15.00        5.8
# 4      ISCGEM860890  01/09/1965   11.9380   126.4270   15.00        5.8
# ...             ...         ...       ...        ...     ...        ...
# 23407    NN00570710  12/28/2016   38.3917  -118.8941   12.30        5.6
# 23408    NN00570744  12/28/2016   38.3777  -118.8957    8.80        5.5
# 23409    US10007NAF  12/28/2016   36.9179   140.4262   10.00        5.9
# 23410    US10007NL0  12/29/2016   -9.0283   118.6639   79.00        6.3
# 23411    US10007NTD  12/30/2016   37.3973   141.4103   11.94        5.5
#
# [23412 rows x 6 columns]

# %%
earthquakes_df['Date']=pd.to_datetime(earthquakes_df['Date'],utc=True)
earthquakes_df['Year'] = earthquakes_df['Date'].dt.year
earthquakes_df
# Out:
#                  ID                      Date  Latitude  Longitude   Depth  \
# 0      ISCGEM860706 1965-01-02 00:00:00+00:00   19.2460   145.6160  131.60
# 1      ISCGEM860737 1965-01-04 00:00:00+00:00    1.8630   127.3520   80.00
# 2      ISCGEM860762 1965-01-05 00:00:00+00:00  -20.5790  -173.9720   20.00
# 3      ISCGEM860856 1965-01-08 00:00:00+00:00  -59.0760   -23.5570   15.00
# 4      ISCGEM860890 1965-01-09 00:00:00+00:00   11.9380   126.4270   15.00
# ...             ...                       ...       ...        ...     ...
# 23407    NN00570710 2016-12-28 00:00:00+00:00   38.3917  -118.8941   12.30
# 23408    NN00570744 2016-12-28 00:00:00+00:00   38.3777  -118.8957    8.80
# 23409    US10007NAF 2016-12-28 00:00:00+00:00   36.9179   140.4262   10.00
# 23410    US10007NL0 2016-12-29 00:00:00+00:00   -9.0283   118.6639   79.00
# 23411    US10007NTD 2016-12-30 00:00:00+00:00   37.3973   141.4103   11.94
#
#        Magnitude  Year
# 0            6.0  1965
# 1            5.8  1965
# 2            6.2  1965
# 3            5.8  1965
# 4            5.8  1965
# ...          ...   ...
# 23407        5.6  2016
# 23408        5.5  2016
# 23409        5.9  2016
# 23410        6.3  2016
# 23411        5.5  2016
#
# [23412 rows x 7 columns]

# %%
earthquakes_df=earthquakes_df[["ID","Date","Year","Latitude","Longitude","Depth","Magnitude"]]

earthquakes_df
# Out:
#                  ID                      Date  Year  Latitude  Longitude  \
# 0      ISCGEM860706 1965-01-02 00:00:00+00:00  1965   19.2460   145.6160
# 1      ISCGEM860737 1965-01-04 00:00:00+00:00  1965    1.8630   127.3520
# 2      ISCGEM860762 1965-01-05 00:00:00+00:00  1965  -20.5790  -173.9720
# 3      ISCGEM860856 1965-01-08 00:00:00+00:00  1965  -59.0760   -23.5570
# 4      ISCGEM860890 1965-01-09 00:00:00+00:00  1965   11.9380   126.4270
# ...             ...                       ...   ...       ...        ...
# 23407    NN00570710 2016-12-28 00:00:00+00:00  2016   38.3917  -118.8941
# 23408    NN00570744 2016-12-28 00:00:00+00:00  2016   38.3777  -118.8957
# 23409    US10007NAF 2016-12-28 00:00:00+00:00  2016   36.9179   140.4262
# 23410    US10007NL0 2016-12-29 00:00:00+00:00  2016   -9.0283   118.6639
# 23411    US10007NTD 2016-12-30 00:00:00+00:00  2016   37.3973   141.4103
#
#         Depth  Magnitude
# 0      131.60        6.0
# 1       80.00        5.8
# 2       20.00        6.2
# 3       15.00        5.8
# 4       15.00        5.8
# ...       ...        ...
# 23407   12.30        5.6
# 23408    8.80        5.5
# 23409   10.00        5.9
# 23410   79.00        6.3
# 23411   11.94        5.5
#
# [23412 rows x 7 columns]

# %%
earthquakes_df2=earthquakes_df[["ID","Date","Latitude","Longitude","Depth","Magnitude"]]

earthquakes_df2
# Out:
#                  ID                      Date  Latitude  Longitude   Depth  \
# 0      ISCGEM860706 1965-01-02 00:00:00+00:00   19.2460   145.6160  131.60
# 1      ISCGEM860737 1965-01-04 00:00:00+00:00    1.8630   127.3520   80.00
# 2      ISCGEM860762 1965-01-05 00:00:00+00:00  -20.5790  -173.9720   20.00
# 3      ISCGEM860856 1965-01-08 00:00:00+00:00  -59.0760   -23.5570   15.00
# 4      ISCGEM860890 1965-01-09 00:00:00+00:00   11.9380   126.4270   15.00
# ...             ...                       ...       ...        ...     ...
# 23407    NN00570710 2016-12-28 00:00:00+00:00   38.3917  -118.8941   12.30
# 23408    NN00570744 2016-12-28 00:00:00+00:00   38.3777  -118.8957    8.80
# 23409    US10007NAF 2016-12-28 00:00:00+00:00   36.9179   140.4262   10.00
# 23410    US10007NL0 2016-12-29 00:00:00+00:00   -9.0283   118.6639   79.00
# 23411    US10007NTD 2016-12-30 00:00:00+00:00   37.3973   141.4103   11.94
#
#        Magnitude
# 0            6.0
# 1            5.8
# 2            6.2
# 3            5.8
# 4            5.8
# ...          ...
# 23407        5.6
# 23408        5.5
# 23409        5.9
# 23410        6.3
# 23411        5.5
#
# [23412 rows x 6 columns]

# %%
earthquakes_df=earthquakes_df.rename(columns={"ID": "id", "Date": "date","Year": "year", "Latitude": "latitude","Longitude": "longitude", "Depth": "depth","Magnitude": "magnitude"})
earthquakes_df
# Out:
#                  id                      date  year  latitude  longitude  \
# 0      ISCGEM860706 1965-01-02 00:00:00+00:00  1965   19.2460   145.6160
# 1      ISCGEM860737 1965-01-04 00:00:00+00:00  1965    1.8630   127.3520
# 2      ISCGEM860762 1965-01-05 00:00:00+00:00  1965  -20.5790  -173.9720
# 3      ISCGEM860856 1965-01-08 00:00:00+00:00  1965  -59.0760   -23.5570
# 4      ISCGEM860890 1965-01-09 00:00:00+00:00  1965   11.9380   126.4270
# ...             ...                       ...   ...       ...        ...
# 23407    NN00570710 2016-12-28 00:00:00+00:00  2016   38.3917  -118.8941
# 23408    NN00570744 2016-12-28 00:00:00+00:00  2016   38.3777  -118.8957
# 23409    US10007NAF 2016-12-28 00:00:00+00:00  2016   36.9179   140.4262
# 23410    US10007NL0 2016-12-29 00:00:00+00:00  2016   -9.0283   118.6639
# 23411    US10007NTD 2016-12-30 00:00:00+00:00  2016   37.3973   141.4103
#
#         depth  magnitude
# 0      131.60        6.0
# 1       80.00        5.8
# 2       20.00        6.2
# 3       15.00        5.8
# 4       15.00        5.8
# ...       ...        ...
# 23407   12.30        5.6
# 23408    8.80        5.5
# 23409   10.00        5.9
# 23410   79.00        6.3
# 23411   11.94        5.5
#
# [23412 rows x 7 columns]

# %%
earthquakes_df.to_csv("earthquakesSQL.csv")

# %%
# create database connection
password=os.environ.get("PASSWORD")
engine= create_engine('postgresql://postgres:'+password+'@localhost:5432/earthquakes2_DB')
connection=engine.connect()
inspector=inspect(engine)
inspector.get_table_names()
# Out:
# ['earthquakes2', 'earthquakes3']

# %%
# load dataframe into database
try:
   df.to_sql(name="earthquakes",con=engine,if_exists="append")
except:
    print("Table is already updated")
# Out:
# Table is already updated

# %%
# query table to confirm dataframe is loaded into database
pd.read_sql_query('select * from earthquakes2', con=engine).head()
# Out:
#              id        date  year  latitude  longitude  depth  magnitude
# 0  ISCGEM860706  1965-01-02  1965    19.246    145.616  131.6        6.0
# 1  ISCGEM860737  1965-01-04  1965     1.863    127.352   80.0        5.8
# 2  ISCGEM860762  1965-01-05  1965   -20.579   -173.972   20.0        6.2
# 3  ISCGEM860856  1965-01-08  1965   -59.076    -23.557   15.0        5.8
# 4  ISCGEM860890  1965-01-09  1965    11.938    126.427   15.0        5.8

# %%
year_groups=pd.read_sql_query('''select year,count(id) from earthquakes2
                                 group by year''',con=engine)
year_groups.head()
# Out:
#    year  count
# 0  1988    489
# 1  1995    591
# 2  1992    533
# 3  1969    323
# 4  2008    508

# %%
year=year_groups["year"]
count=year_groups["count"]
frequency= plt.scatter(year, count, color="red", label="frequency")
plt.title("Earthquake frequency Over Time")
plt.xlabel("Year")
plt.ylabel("Total Earthquake Occurance")
plt.savefig("Earthquake frequency Over Time")
plt.show()

# %%
# scatter plot and regression  
x_values=year_groups["year"]
y_values=year_groups["count"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and earthquake frequency is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(1980,380),fontsize=12)
plt.annotate(eq,(1990,380),fontsize=12)
plt.title("Earthquake frequency Over Time",fontsize=15)
plt.xlabel("Year",fontsize=12)
plt.ylabel("Earthquake frequency Over Time",fontsize=12)
plt.savefig("Earthquake frequency Over Time")
plt.show()
# Out:
# The correlation between year and earthquake frequency is 0.71

# %%
magnitude_means=pd.read_sql_query('''select year,AVG(magnitude) from earthquakes2
                                 group by year''',con=engine)
magnitude_means.head()
# Out:
#    year       avg
# 0  1988  5.848875
# 1  1995  5.904822
# 2  1992  5.882702
# 3  1969  6.009350
# 4  2008  5.908858

# %%
magnitude_means.to_csv("yearmag.csv")

# %%
year=magnitude_means["year"]
avg=magnitude_means["avg"]
magnitude_mean= plt.scatter(year, avg, color="blue", label="magnitude_mean")
plt.title("Average Magnitude over Time")
plt.xlabel("Year")
plt.ylabel("Average Magnitude")
plt.savefig("Average Magnitude over Time")
plt.show()

# %%
# scatter plot and regression  
x_values=magnitude_means["year"]
y_values=magnitude_means["avg"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and average magnitude is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(eq,(1990,6),fontsize=12)
plt.title("Average Magnitude over Time")
plt.xlabel("Year")
plt.ylabel("Average Magnitude")
plt.savefig("Average Magnitude over Time")
plt.show()
# Out:
# The correlation between year and average magnitude is -0.34

# %%
depth_means=pd.read_sql_query('''select year,AVG(depth) from earthquakes2
                                 group by year''',con=engine)
depth_means.head()
# Out:
#    year        avg
# 0  1988  75.802249
# 1  1995  74.227936
# 2  1992  71.412068
# 3  1969  61.356347
# 4  2008  61.178937

# %%
year=depth_means["year"]
averageDepth=depth_means["avg"]
depth_mean= plt.scatter(year, averageDepth, color="blue", label="magnitude_mean")
plt.title("Average Depth over Time")
plt.xlabel("Year")
plt.ylabel("Average Depth")
plt.savefig("Average Depth over Time")
plt.show()

# %%
x_values=depth_means["year"]
y_values=depth_means["avg"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and average depth is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(eq,(1980,80),fontsize=12)
plt.title("Average Depth over Time")
plt.xlabel("Year")
plt.ylabel("Average Depth")
plt.savefig("Average Depth over Time")
plt.show()
# Out:
# The correlation between year and average depth is -0.26

# %%
bin1=pd.read_sql_query('''select year,count(magnitude) 
                        from earthquakes2
                        where magnitude BETWEEN 5.5 AND 6
                        group by year''',con=engine)
bin1.head()
# Out:
#    year  count
# 0  1988    384
# 1  1995    432
# 2  1992    393
# 3  1969    205
# 4  2008    366

# %%
year=bin1["year"]
bin1count=bin1["count"]
bin1_plot= plt.scatter(year, bin1count, color="blue", label="magnitude_mean")
plt.title("Magnitude(5.5-6) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin1 over Time")
plt.show()

# %%
x_values=bin1["year"]
y_values=bin1["count"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and count of earthquakes with magnitude(5.5-6) is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(eq,(2000,250),fontsize=12)
plt.title("Magnitude(5.5-6) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin1 over Time")
plt.show()
# Out:
# The correlation between year and count of earthquakes with magnitude(5.5-6) is 0.7

# %%
bin2=pd.read_sql_query('''select year,count(magnitude) 
                        from earthquakes2
                        where magnitude BETWEEN 6 AND 6.5
                        group by year''',con=engine)
bin2.head()
# Out:
#    year  count
# 0  1988     88
# 1  1995    149
# 2  1992    139
# 3  1969    116
# 4  2008    143

# %%
year=bin2["year"]
bin2count=bin2["count"]
bin1_plot= plt.scatter(year, bin2count, color="blue", label="magnitude_mean")
plt.title("Magnitude(6-6.5) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin2 over Time")
plt.show()

# %%
x_values=bin2["year"]
y_values=bin2["count"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and count of earthquakes with magnitude(6-6.5) is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(eq,(2000,80),fontsize=12)
plt.title("Magnitude(6-6.5) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin2 over Time")
plt.show()
# Out:
# The correlation between year and count of earthquakes with magnitude(6-6.5) is 0.47

# %%
bin3=pd.read_sql_query('''select year,count(magnitude) 
                        from earthquakes2
                        where magnitude BETWEEN 6.5 AND 7
                        group by year''',con=engine)
bin3.head()
# Out:
#    year  count
# 0  1988     37
# 1  1995     48
# 2  1992     39
# 3  1969     31
# 4  2008     37

# %%
year=bin3["year"]
bin3count=bin3["count"]
bin1_plot= plt.scatter(year, bin3count, color="blue", label="magnitude_mean")
plt.title("Magnitude(6.5-7) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin3 over Time")
plt.show()

# %%
x_values=bin3["year"]
y_values=bin3["count"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and count of earthquakes with magnitude(6.5-7) is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(eq,(2000,20),fontsize=12)
plt.title("Magnitude(6.5-7) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin3 over Time")
plt.show()
# Out:
# The correlation between year and count of earthquakes with magnitude(6.5-7) is 0.33

# %%
bin4=pd.read_sql_query('''select year,count(magnitude) 
                        from earthquakes2
                        where magnitude BETWEEN 7 AND 8
                        group by year''',con=engine)
bin4.head()
# Out:
#    year  count
# 0  1988     11
# 1  1995     20
# 2  1992     13
# 3  1969     14
# 4  2008     12

# %%
year=bin4["year"]
bin4count=bin4["count"]
bin1_plot= plt.scatter(year, bin4count, color="blue", label="magnitude_mean")
plt.title("Magnitude(7-8) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin4 over Time")
plt.show()

# %%
x_values=bin4["year"]
y_values=bin4["count"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and count of earthquakes with magnitude(7-8) is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(eq,(1990,10),fontsize=12)
plt.title("Magnitude(7-8) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin4 over Time")
plt.show()
# Out:
# The correlation between year and count of earthquakes with magnitude(7-8) is 0.24

# %%
ddf=pd.read_sql_query('''select *
                        from earthquakes2
                        where magnitude BETWEEN 8 AND 10
                        ''',con=engine)
ddf
# Out:
#                               id        date  year  latitude  longitude  \
# 0                   ISCGEM861299  1965-01-24  1965   -2.6080   125.9520
# 1      OFFICIAL19650204050122_30  1965-02-04  1965   51.2510   178.7150
# 2                   ISCGEM842581  1966-10-17  1966  -10.6650   -78.2280
# 3                   ISCGEM821946  1968-05-16  1968   40.8600   143.4350
# 4                   ISCGEM794176  1970-07-31  1970   -1.5970   -72.5320
# 5                   ISCGEM782181  1971-07-14  1971   -5.5240   153.8500
# 6                   ISCGEM782684  1971-07-26  1971   -4.8170   153.1720
# 7                   ISCGEM765501  1972-12-02  1972    6.4050   126.6400
# 8                     USP0000EE7  1976-01-14  1976  -28.4270  -177.6570
# 9                     USP0002CCZ  1985-03-03  1985  -33.1350   -71.8710
# 10                    USP0002JWE  1985-09-19  1985   18.1900  -102.5330
# 11                    USP0002TMU  1986-05-07  1986   51.5200  -174.7760
# 12                    USP0003VJ7  1989-05-23  1989  -52.3410   160.5680
# 13                    USP0006DZC  1994-06-09  1994  -13.8410   -67.5530
# 14                    USP0006KDP  1994-10-04  1994   43.7730   147.3210
# 15                    USP000714T  1995-07-30  1995  -23.3400   -70.2940
# 16                    USP00074VC  1995-10-09  1995   19.0550  -104.2050
# 17                    USP0007D1W  1996-02-17  1996   -0.8910   136.9520
# 18                    USP0008HZD  1998-03-25  1998  -62.8770   149.5270
# 19                    USP000A3QQ  2000-11-16  2000   -3.9800   152.1690
# 20  OFFICIAL20010623203314130_33  2001-06-23  2001  -16.2650   -73.6410
# 21                    USP000C8KV  2003-09-25  2003   41.8150   143.9100
# 22                    USP000DB93  2004-12-23  2004  -49.3120   161.3450
# 23  OFFICIAL20041226005853450_30  2004-12-26  2004    3.2950    95.9820
# 24  OFFICIAL20050328160936530_30  2005-03-28  2005    2.0850    97.1080
# 25                    USP000EG5G  2006-05-03  2006  -20.1870  -174.1230
# 26                    USP000EXFN  2006-11-15  2006   46.5920   153.2660
# 27                    USP000F2AB  2007-01-13  2007   46.2430   154.5240
# 28                    USP000F83M  2007-04-01  2007   -8.4660   157.0430
# 29                    USP000FJTA  2007-08-15  2007  -13.3860   -76.6030
# 30  OFFICIAL20070912111026830_34  2007-09-12  2007   -4.4380   101.3670
# 31                    USP000H1YS  2009-09-29  2009  -15.4890  -172.0950
# 32  OFFICIAL20100227063411530_30  2010-02-27  2010  -36.1220   -72.8980
# 33  OFFICIAL20110311054624120_30  2011-03-11  2011   38.2970   142.3730
# 34  OFFICIAL20120411083836720_20  2012-04-11  2012    2.3270    93.0630
# 35                    USP000JHJB  2012-04-11  2012    0.8020    92.4630
# 36                    USC000F1S0  2013-02-06  2013  -10.7990   165.1140
# 37                    USB000H4JH  2013-05-24  2013   54.8920   153.2210
# 38                    USC000NZVD  2014-04-01  2014  -19.6097   -70.7691
# 39                    US20003K7A  2015-09-16  2015  -31.5729   -71.6744
#
#      depth  magnitude
# 0    20.00        8.2
# 1    30.30        8.7
# 2    40.00        8.1
# 3    29.90        8.2
# 4   644.80        8.0
# 5    40.00        8.0
# 6    40.00        8.1
# 7    60.00        8.0
# 8    33.00        8.0
# 9    33.00        8.0
# 10   27.90        8.0
# 11   33.00        8.0
# 12   10.00        8.2
# 13  631.30        8.2
# 14   14.00        8.3
# 15   45.60        8.0
# 16   33.00        8.0
# 17   33.00        8.2
# 18   10.00        8.1
# 19   33.00        8.0
# 20   33.00        8.4
# 21   27.00        8.3
# 22   10.00        8.1
# 23   30.00        9.1
# 24   30.00        8.6
# 25   55.00        8.0
# 26   10.00        8.3
# 27   10.00        8.1
# 28   24.00        8.1
# 29   39.00        8.0
# 30   34.00        8.4
# 31   18.00        8.1
# 32   22.90        8.8
# 33   29.00        9.1
# 34   20.00        8.6
# 35   25.10        8.2
# 36   24.00        8.0
# 37  598.10        8.3
# 38   25.00        8.2
# 39   22.44        8.3

# %%
bin5=pd.read_sql_query('''select year,count(magnitude) 
                        from earthquakes2
                        where magnitude BETWEEN 8 AND 9.5
                        group by year''',con=engine)
bin5.head()
# Out:
#    year  count
# 0  1965      2
# 1  1966      1
# 2  1968      1
# 3  1970      1
# 4  1971      2

# %%
year=bin5["year"]
bin5count=bin5["count"]
bin1_plot= plt.scatter(year, bin5count, color="blue", label="magnitude_mean")
plt.title("Magnitude(8-10) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin5 over Time")
plt.show()

# %%
x_values=bin5["year"]
y_values=bin5["count"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between year and count of earthquakes with magnitude(8-9.5) is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
eq="r="+str(round(r_value,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(eq,(1980,2.5),fontsize=12)
plt.title("Magnitude(8-9.5) over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.savefig("Magnitude bin5 over Time")
plt.show()
# Out:
# The correlation between year and count of earthquakes with magnitude(8-9.5) is 0.11
